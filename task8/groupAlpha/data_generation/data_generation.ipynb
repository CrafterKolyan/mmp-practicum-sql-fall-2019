# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Создание бд (не работает сука)

# %%
import os
import pymysql
import sys
f = open('../create_logic.sql')
load_sql = f.read()
print(load_sql)
host = '127.0.0.1'
user = 'user'
password = 'guizeppe'
try:
    con = pymysql.connect(host=host,
                            user=user,
                            password=password,
                            autocommit=True,
                            local_infile=1)
    print('Connected to DB: {}'.format(host))
    # Create cursor and execute Load SQL
    cursor = con.cursor()
    cursor.execute(load_sql)
    print('Succuessfully loaded the table from csv.')
    con.close()
except Exception as e:
    print('Error: {}'.format(str(e)))
    sys.exit(1)
# Out:
# -- MySQL Script generated by MySQL Workbench
# -- Tue Dec 10 18:52:12 2019
# -- Model: New Model    Version: 1.0
# -- MySQL Workbench Forward Engineering
#
# SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0;
# SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0;
# SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='ONLY_FULL_GROUP_BY,STRICT_TRANS_TABLES,NO_ZERO_IN_DATE,NO_ZERO_DATE,ERROR_FOR_DIVISION_BY_ZERO,NO_ENGINE_SUBSTITUTION';
#
# -- -----------------------------------------------------
# -- Schema logic
# -- -----------------------------------------------------
# DROP SCHEMA IF EXISTS `logic` ;
#
# -- -----------------------------------------------------
# -- Schema logic
# -- -----------------------------------------------------
# CREATE SCHEMA IF NOT EXISTS `logic` DEFAULT CHARACTER SET utf8 ;
# USE `logic` ;
#
# -- -----------------------------------------------------
# -- Table `logic`.`User`
# -- -----------------------------------------------------
# ...

# %% [markdown]
# # Загрузка данных

# %%
import pymysql
import os
import sys
def csv_to_mysql(file_name, table_name):
    '''
    This function load a csv file to MySQL table according to
    the load_sql statement.
    '''
    
    path = os.path.abspath(os.curdir)
    path = os.path.join(path, file_name)
    load_sql = "LOAD DATA LOCAL INFILE '" + path + "' INTO TABLE " + table_name + " FIELDS TERMINATED BY ',' ENCLOSED BY '" +'"'+"' IGNORE 1 LINES;"
    host = '127.0.0.1'
    user = 'user'
    password = 'guizeppe'
    try:
        con = pymysql.connect(host=host,
                                user=user,
                                password=password,
                                autocommit=True,
                                local_infile=1)
        print('Connected to DB: {}'.format(host))
        # Create cursor and execute Load SQL
        cursor = con.cursor()
        cursor.execute(load_sql)
        print('Succuessfully loaded the table from csv.')
        con.close()
        
    except Exception as e:
        print('Error: {}'.format(str(e)))
        sys.exit(1)


#file_name = 'users.csv'
#csv_to_mysql('users.csv', 'data_vault.Users')

# %% [markdown]
# ### Loading pure tables

# %%
csv_to_mysql('users.csv', 'data.Users')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('groups.csv', 'data.Groups')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('students.csv', 'data.Students')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('teachers.csv', 'data.Teachers')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('assignments.csv', 'data.Assignments')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('tasks.csv', 'data.Tasks')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('submissions.csv', 'data.Submissions')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('supervisors.csv', 'data.Supervisors')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('grades.csv', 'data.Grades')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1062, "Duplicate entry '1' for key 'PRIMARY'")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1062, "Duplicate entry '2' for key 'PRIMARY'")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1062, "Duplicate entry '3' for key 'PRIMARY'")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1062, "Duplicate entry '4' for key 'PRIMARY'")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1062, "Duplicate entry '5' for key 'PRIMARY'")
#   result = self._query(query)
# ...

# %%
csv_to_mysql('student_comments.csv', 'data.StudentsComments')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 55")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 56")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 60")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 130")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 131")
#   result = self._query(query)
# ...

# %%
csv_to_mysql('supervisor_comments.csv', 'data.SupervisorsComments')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 22")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 23")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 60")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 61")
#   result = self._query(query)
# /home/dmitry/.local/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1264, "Out of range value for column 'Date' at row 84")
#   result = self._query(query)
# ...

# %%
csv_to_mysql('users.csv', 'logic.Users')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('groups.csv', 'logic.Groups')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('students.csv', 'logic.Students')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('teachers.csv', 'logic.Teachers')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('assignments.csv', 'logic.Assignment')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('tasks.csv', 'logic.Task')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('submissions.csv', 'logic.Submissions')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('supervisors.csv', 'logic.Supervisors')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.

# %%
csv_to_mysql('grades.csv', 'logic.Grades')
# Out:
# Connected to DB: 127.0.0.1
# Succuessfully loaded the table from csv.
